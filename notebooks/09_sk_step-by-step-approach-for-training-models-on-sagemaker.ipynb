# %% [markdown]
# ## Introduction
# The goal of this notebook is show how to train a PCA model on AWS Sagemaker. The training data resides on S3 in `s3://skuchkula-sagemaker-airbnb/` location. Objective is to apply Principal Components Analysis (PCA) on airbnb locations located in NYC.

# %% [markdown]
# ### STEP 1: Create an S3 bucket which contains sagemaker name in it.
# Having the sagemaker name is not a requirement. However, as per Amazon documentation:
#
# > Note:
# Amazon SageMaker needs permission to access these buckets. You grant permission with an IAM role, which you create in the next step when you create an Amazon SageMaker notebook instance. This IAM role automatically gets permissions to access any bucket that has sagemaker in the name. It gets these permissions through the AmazonSageMakerFullAccess policy, which Amazon SageMaker attaches to the role. If you add a policy to the role that grants the SageMaker service principal S3FullAccess permission, the name of the bucket does not need to contain sagemaker.

# %% [markdown]
# ### STEP 2: Create an Amazon SageMaker Notebook instance
# An Amazon SageMaker notebook instance is a fully managed machine learning (ML) Amazon Elastic Compute Cloud (Amazon EC2) compute instance that runs the Jupyter Notebook App. You use the notebook instance to create and manage Jupyter notebooks that you can use to prepare and process data and to train and deploy machine learning models.
#
# To create an Amazon SageMaker notebook instance
#
# - Open the Amazon SageMaker console at https://console.aws.amazon.com/sagemaker/.
#
# - Choose Notebook instances, then choose Create notebook instance.
#
# - On the Create notebook instance page, provide the following information (if a field is not mentioned, leave the default values):
#
# - For Notebook instance name, type a name for your notebook instance.
#
# - For Instance type, choose ml.t2.medium. This is the least expensive instance type that notebook instances support, and it suffices for this exercise.
#
# - For IAM role, choose Create a new role, then choose Create role.
#
# - Choose Create notebook instance.
#
# In a few minutes, Amazon SageMaker launches an ML compute instance—in this case, a notebook instance—and attaches an ML storage volume to it. The notebook instance has a preconfigured Jupyter notebook server and a set of Anaconda libraries.

# %% [markdown]
# ### Step 3: Create notebook instance and start writing code

# %%
# data managing and display libs
import pandas as pd
import numpy as np
import os
import io

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 

# sagemaker libraries
import boto3
import sagemaker

# %% [markdown]
# ### Step 4:  Get data from S3

# %%
# boto3 client to get S3 data
s3_client = boto3.client('s3')
bucket_name='skuchkula-sagemaker-airbnb'

# %%
# get a list of objects in the bucket
obj_list=s3_client.list_objects(Bucket=bucket_name)

# print object(s)in S3 bucket
files=[]
for contents in obj_list['Contents']:
    files.append(contents['Key'])
    
print(files)
# Out:
# ['detailed_listings.csv', 'summary_listings.csv']

# %%
# there is one file --> one key
detailed_listings=files[0]
summary_listings=files[1]

# %%
# check the file formats
file_name = detailed_listings

# get an S3 object by passing in the bucket and file name
data_object = s3_client.get_object(Bucket=bucket_name, Key=file_name)

# what info does the object contain?
display(data_object)
# Out:
# {'ResponseMetadata': {'RequestId': '707B8D555C02A9CF',
#   'HostId': 'Tetif8MjItlgvMLDkfkClqVou7yYvvQRcMuNPqoQZ9ul7uBYuFMnnojaDBR1ip0Vnrzq08at2Wk=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Tetif8MjItlgvMLDkfkClqVou7yYvvQRcMuNPqoQZ9ul7uBYuFMnnojaDBR1ip0Vnrzq08at2Wk=',
#    'x-amz-request-id': '707B8D555C02A9CF',
#    'date': 'Thu, 03 Oct 2019 21:27:43 GMT',
#    'last-modified': 'Thu, 03 Oct 2019 20:54:13 GMT',
#    'etag': '"5b3292fef934f7912d1b6fbca919cde7"',
#    'accept-ranges': 'bytes',
#    'content-type': 'text/csv',
#    'content-length': '7072663',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2019, 10, 3, 20, 54, 13, tzinfo=tzutc()),
#  'ContentLength': 7072663,
#  'ETag': '"5b3292fef934f7912d1b6fbca919cde7"',
#  'ContentType': 'text/csv',
#  'Metadata': {},
#  'Body': <botocore.response.StreamingBody at 0x7f9aaed6c940>}

# %%
# information is in the "Body" of the object
data_body = data_object["Body"].read()
print('Data type: ', type(data_body))
# Out:
# Data type:  <class 'bytes'>

# %%
# read in bytes data
data_stream = io.BytesIO(data_body)

# create a dataframe
counties_df = pd.read_csv(data_stream, header=0, delimiter=",") 
counties_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2595                             Skylit Midtown Castle     2845
# 1  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 2  3831                   Cozy Entire Floor of Brownstone     4869
# 3  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 1    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 2  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 3        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 4        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    225               1                 46  2019-07-14
# 1     Private room    150               3                  0         NaN
# 2  Entire home/apt     89               1                274  2019-07-26
# 3  Entire home/apt     80              10                  9  2018-11-19
# 4  Entire home/apt    200               3                 75  2019-07-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.39                               2               288
# 1                NaN                               1               365
# 2               4.64                               1               212
# 3               0.10                               1                 0
# 4               0.60                               1               127

# %%
def get_data_frame(bucket_name, file_name):
    # get an S3 object by passing in the bucket and file name
    data_object = s3_client.get_object(Bucket=bucket_name, Key=file_name)
    
    # information is in the "Body" of the object
    data_body = data_object["Body"].read()
    
    # read in bytes data
    data_stream = io.BytesIO(data_body)
    
    # create a dataframe
    df = pd.read_csv(data_stream, header=0, delimiter=",", low_memory=False)
    
    return df

# %%
df_summary_listings = get_data_frame(bucket_name, summary_listings)
df_detailed_listings = get_data_frame(bucket_name, detailed_listings)

# %%
df_summary_listings.head()
# Out:
#      id                                              name  host_id  \
# 0  2595                             Skylit Midtown Castle     2845
# 1  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 2  3831                   Cozy Entire Floor of Brownstone     4869
# 3  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 1    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 2  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 3        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 4        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    225               1                 46  2019-07-14
# 1     Private room    150               3                  0         NaN
# 2  Entire home/apt     89               1                274  2019-07-26
# 3  Entire home/apt     80              10                  9  2018-11-19
# 4  Entire home/apt    200               3                 75  2019-07-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.39                               2               288
# 1                NaN                               1               365
# 2               4.64                               1               212
# 3               0.10                               1                 0
# 4               0.60                               1               127

# %%
df_detailed_listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20190806030549   2019-08-07
# 1  3647  https://www.airbnb.com/rooms/3647  20190806030549   2019-08-06
# 2  3831  https://www.airbnb.com/rooms/3831  20190806030549   2019-08-06
# 3  5022  https://www.airbnb.com/rooms/5022  20190806030549   2019-08-06
# 4  5099  https://www.airbnb.com/rooms/5099  20190806030549   2019-08-06
#
#                                                name  \
# 0                             Skylit Midtown Castle
# 1               THE VILLAGE OF HARLEM....NEW YORK !
# 2                   Cozy Entire Floor of Brownstone
# 3  Entire Apt: Spacious Studio/Loft by central park
# 4         Large Cozy 1 BR Apartment In Midtown East
#
#                                              summary  \
# 0  Find your romantic getaway to this beautiful, ...
# 1                                                NaN
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 3                                                NaN
# 4  My large 1 bedroom apartment is true New York ...
#
#                                                space  \
# 0  - Spacious (500+ft²), immaculate and nicely fu...
# 1  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 2  Greetings!      We own a double-duplex brownst...
# 3  Loft apartment with high ceiling and wood floo...
# 4  I have a large 1 bedroom apartment centrally l...
#
#                                          description experiences_offered  \
# 0  Find your romantic getaway to this beautiful, ...                none
# 1  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...                none
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...                none
# 3  Loft apartment with high ceiling and wood floo...                none
# 4  My large 1 bedroom apartment is true New York ...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Centrally located in the heart of Manhattan ju...  ...                f
# 1                                                NaN  ...                f
# 2  Just the right mix of urban center and local n...  ...                f
# 3                                                NaN  ...                f
# 4  My neighborhood in Midtown East is called Murr...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                t
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               1
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            1               0.39
# 1                                            0                NaN
# 2                                            0               4.64
# 3                                            0               0.10
# 4                                            0               0.60
#
# [5 rows x 106 columns]

# %% [markdown]
# The Detailed listings contains about 106 different features for each of the Airbnb locations. We need to do some EDA to check if we can trim down some features.

# %%
print("Summary Listings row, cols: ", df_summary_listings.shape)
print("Detailed Listings row, cols: ", df_detailed_listings.shape)
# Out:
# Summary Listings row, cols:  (48864, 16)
# Detailed Listings row, cols:  (48864, 106)

# %% [markdown]
# The summary listings contains a small subset of features contained in the detailed listings. Summary listings is good for visualization purposes, but for machine learning models, it is better to have more features from which the model can learn.

# %%
df_summary_listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# check how the data types are distributed.
# pandas does its best to interpret the datatype while reading in
# however it is our duty to check if the datatype makes sense
df_detailed_listings.dtypes.value_counts()
# Out:
# object     63
# float64    22
# int64      21
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df_detailed_listings.select_dtypes(include=['object']).columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'picture_url',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'is_location_exact',
#        'property_type', 'room_type', 'bed_type', 'amenities', 'price',
#        'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee',
#        'extra_people', 'calendar_updated', 'has_availability',
#        'calendar_last_scraped', 'first_review', 'last_review',
#        'requires_license', 'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification'],
#       dtype='object')

# %%
print(pd.get_option("display.max_columns"))
pd.set_option("display.max_columns", 100)
print(pd.get_option("display.max_columns"))
# Out:
# -1
# 100

# %%
drop_object_cols = ['listing_url',
             'last_scraped',
             'name',
             'picture_url',
             'host_url',
             'host_name',
             'host_since',
             'host_location',
             'host_about',
             'host_thumbnail_url',
             'host_picture_url',
             'host_neighbourhood',
             'street',
             'neighbourhood',
             'neighbourhood_cleansed',
             'neighbourhood_group_cleansed',
             'city',
             'state',
             'zipcode',
             'market',
             'smart_location',
             'country_code',
             'country',
             'calendar_updated',
             'calendar_last_scraped',
             'first_review',
             'last_review' 
            ]

# %%
df_detailed_listings.select_dtypes(include=['object']).head()
# Out:
#                          listing_url last_scraped  \
# 0  https://www.airbnb.com/rooms/2595   2019-08-07
# 1  https://www.airbnb.com/rooms/3647   2019-08-06
# 2  https://www.airbnb.com/rooms/3831   2019-08-06
# 3  https://www.airbnb.com/rooms/5022   2019-08-06
# 4  https://www.airbnb.com/rooms/5099   2019-08-06
#
#                                                name  \
# 0                             Skylit Midtown Castle
# 1               THE VILLAGE OF HARLEM....NEW YORK !
# 2                   Cozy Entire Floor of Brownstone
# 3  Entire Apt: Spacious Studio/Loft by central park
# 4         Large Cozy 1 BR Apartment In Midtown East
#
#                                              summary  \
# 0  Find your romantic getaway to this beautiful, ...
# 1                                                NaN
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 3                                                NaN
# 4  My large 1 bedroom apartment is true New York ...
#
#                                                space  \
# 0  - Spacious (500+ft²), immaculate and nicely fu...
# 1  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 2  Greetings!      We own a double-duplex brownst...
# 3  Loft apartment with high ceiling and wood floo...
# 4  I have a large 1 bedroom apartment centrally l...
#
#                                          description experiences_offered  \
# 0  Find your romantic getaway to this beautiful, ...                none
# 1  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...                none
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...                none
# 3  Loft apartment with high ceiling and wood floo...                none
# 4  My large 1 bedroom apartment is true New York ...                none
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1                                                NaN
# 2  Just the right mix of urban center and local n...
# 3                                                NaN
# 4  My neighborhood in Midtown East is called Murr...
#
#                                                notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Read My Full Listing For All Information. New ...
#
#                                              transit  \
# 0  Apartment is located on 37th Street between 5t...
# 1                                                NaN
# 2  B52 bus for a 10-minute ride to downtown Brook...
# 3                                                NaN
# 4  From the apartment is a 10 minute walk to Gran...
#
#                                               access  \
# 0  Guests have full access to the kitchen, bathro...
# 1                                                NaN
# 2  You will have exclusive use of and access to: ...
# 3                                                NaN
# 4                      I will meet you upon arrival.
#
#                                          interaction  \
# 0  I am a Sound Therapy Practitioner and Kundalin...
# 1                                                NaN
# 2  We'll be around, but since you have the top fl...
# 3                                                NaN
# 4  I usually check in with guests via text or ema...
#
#                                          house_rules  \
# 0  Make yourself at home, respect the space and t...
# 1  Upon arrival please have a legibile copy of yo...
# 2  Smoking - outside please; pets allowed but ple...
# 3  Please be considerate when staying in the apar...
# 4  • Check-in time is 2PM. • Check-out time is 12...
#
#                                          picture_url  \
# 0  https://a0.muscache.com/im/pictures/f0813a11-4...
# 1  https://a0.muscache.com/im/pictures/838341/9b3...
# 2  https://a0.muscache.com/im/pictures/e49999c2-9...
# 3  https://a0.muscache.com/im/pictures/feb453bd-f...
# 4  https://a0.muscache.com/im/pictures/be2fdcf6-e...
#
#                                  host_url    host_name  host_since  \
# 0  https://www.airbnb.com/users/show/2845     Jennifer  2008-09-09
# 1  https://www.airbnb.com/users/show/4632    Elisabeth  2008-11-25
# 2  https://www.airbnb.com/users/show/4869  LisaRoxanne  2008-12-07
# 3  https://www.airbnb.com/users/show/7192        Laura  2009-01-29
# 4  https://www.airbnb.com/users/show/7322        Chris  2009-02-02
#
#                        host_location  \
# 0  New York, New York, United States
# 1  New York, New York, United States
# 2  New York, New York, United States
# 3      Miami, Florida, United States
# 4  New York, New York, United States
#
#                                           host_about  host_response_time  \
# 0  A New Yorker since 2000! My passion is creatin...  within a few hours
# 1  Make Up Artist National/ (Website hidden by Ai...        within a day
# 2     Laid-back bi-coastal actor/professor/attorney.      within an hour
# 3  I have been a NYer for almost 10 years. I came...                 NaN
# 4  I'm an artist, writer, traveler, and a native ...  within a few hours
#
#   host_response_rate host_is_superhost  \
# 0                90%                 f
# 1               100%                 f
# 2                90%                 f
# 3                NaN                 f
# 4                90%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/2845/profile_...
# 1  https://a0.muscache.com/im/users/4632/profile_...
# 2  https://a0.muscache.com/im/users/4869/profile_...
# 3  https://a0.muscache.com/im/users/7192/profile_...
# 4  https://a0.muscache.com/im/pictures/user/26745...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/2845/profile_...            Midtown
# 1  https://a0.muscache.com/im/users/4632/profile_...             Harlem
# 2  https://a0.muscache.com/im/users/4869/profile_...       Clinton Hill
# 3  https://a0.muscache.com/im/users/7192/profile_...        East Harlem
# 4  https://a0.muscache.com/im/pictures/user/26745...  Flatiron District
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'kba', 'work_ema...                    t
# 1  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 2               ['email', 'phone', 'reviews', 'kba']                    t
# 3   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#   host_identity_verified                       street neighbourhood  \
# 0                      t  New York, NY, United States       Midtown
# 1                      t  New York, NY, United States        Harlem
# 2                      t  Brooklyn, NY, United States      Brooklyn
# 3                      t  New York, NY, United States   East Harlem
# 4                      f  New York, NY, United States  Midtown East
#
#   neighbourhood_cleansed neighbourhood_group_cleansed      city state zipcode  \
# 0                Midtown                    Manhattan  New York    NY   10018
# 1                 Harlem                    Manhattan  New York    NY   10027
# 2           Clinton Hill                     Brooklyn  Brooklyn    NY   11238
# 3            East Harlem                    Manhattan  New York    NY   10029
# 4            Murray Hill                    Manhattan  New York    NY   10016
#
#      market smart_location country_code        country is_location_exact  \
# 0  New York   New York, NY           US  United States                 f
# 1  New York   New York, NY           US  United States                 t
# 2  New York   Brooklyn, NY           US  United States                 t
# 3  New York   New York, NY           US  United States                 t
# 4  New York   New York, NY           US  United States                 f
#
#   property_type        room_type       bed_type  \
# 0     Apartment  Entire home/apt       Real Bed
# 1     Apartment     Private room  Pull-out Sofa
# 2   Guest suite  Entire home/apt       Real Bed
# 3     Apartment  Entire home/apt       Real Bed
# 4     Apartment  Entire home/apt       Real Bed
#
#                                            amenities    price weekly_price  \
# 0  {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  $225.00    $1,995.00
# 1  {"Cable TV",Internet,Wifi,"Air conditioning",K...  $150.00          NaN
# 2  {TV,"Cable TV",Internet,Wifi,"Air conditioning...   $89.00      $575.00
# 3  {Internet,Wifi,"Air conditioning",Kitchen,Elev...   $80.00      $600.00
# 4  {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...  $200.00          NaN
#
#   monthly_price security_deposit cleaning_fee extra_people calendar_updated  \
# 0           NaN          $350.00      $100.00        $0.00       a week ago
# 1           NaN          $200.00       $75.00       $20.00    35 months ago
# 2     $2,100.00          $500.00          NaN        $0.00            today
# 3     $1,600.00          $100.00       $80.00       $20.00     4 months ago
# 4           NaN          $300.00      $125.00      $100.00       4 days ago
#
#   has_availability calendar_last_scraped first_review last_review  \
# 0                t            2019-08-07   2009-11-21  2019-07-14
# 1                t            2019-08-06          NaN         NaN
# 2                t            2019-08-06   2014-09-30  2019-07-26
# 3                t            2019-08-06   2012-03-20  2018-11-19
# 4                t            2019-08-06   2009-04-20  2019-07-21
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification
# 0                             t                                t
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             t                                t

# %%
df_detailed_listings.select_dtypes(include=['float64']).columns
# Out:
# Index(['thumbnail_url', 'medium_url', 'xl_picture_url', 'host_acceptance_rate',
#        'host_listings_count', 'host_total_listings_count', 'latitude',
#        'longitude', 'bathrooms', 'bedrooms', 'beds', 'square_feet',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
drop_float_cols = ['thumbnail_url',
                   'medium_url',
                   'xl_picture_url',
                   'latitude',
                   'longitude'
                  ]

# %%
df_detailed_listings.select_dtypes(include=['float64']).head()
# Out:
#    thumbnail_url  medium_url  xl_picture_url  host_acceptance_rate  \
# 0            NaN         NaN             NaN                   NaN
# 1            NaN         NaN             NaN                   NaN
# 2            NaN         NaN             NaN                   NaN
# 3            NaN         NaN             NaN                   NaN
# 4            NaN         NaN             NaN                   NaN
#
#    host_listings_count  host_total_listings_count  latitude  longitude  \
# 0                  5.0                        5.0  40.75362  -73.98377
# 1                  1.0                        1.0  40.80902  -73.94190
# 2                  1.0                        1.0  40.68514  -73.95976
# 3                  1.0                        1.0  40.79851  -73.94399
# 4                  1.0                        1.0  40.74767  -73.97500
#
#    bathrooms  bedrooms  beds  square_feet  minimum_nights_avg_ntm  \
# 0        1.0       0.0   1.0          NaN                     1.0
# 1        1.0       1.0   1.0          NaN                     3.0
# 2        1.0       1.0   4.0        500.0                     1.0
# 3        1.0       NaN   1.0          NaN                    10.0
# 4        1.0       1.0   1.0          NaN                     3.0
#
#    maximum_nights_avg_ntm  review_scores_rating  review_scores_accuracy  \
# 0                  1125.0                  95.0                    10.0
# 1                     7.0                   NaN                     NaN
# 2                   730.0                  90.0                    10.0
# 3                   120.0                  93.0                    10.0
# 4                    21.0                  89.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                        NaN                    NaN
# 2                        9.0                   10.0
# 3                        9.0                   10.0
# 4                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                          NaN                     NaN                  NaN
# 2                          9.0                    10.0                  9.0
# 3                         10.0                     9.0                 10.0
# 4                         10.0                     9.0                  9.0
#
#    reviews_per_month
# 0               0.39
# 1                NaN
# 2               4.64
# 3               0.10
# 4               0.60

# %%
df_detailed_listings.select_dtypes(include=['int64']).columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'accommodates', 'guests_included',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms'],
#       dtype='object')

# %%
drop_int_cols = ['scrape_id',
                 'host_id',
                 'minimum_minimum_nights',
                 'maximum_minimum_nights',
                 'minimum_maximum_nights',
                 'maximum_maximum_nights'
                ]

# %%
df_detailed_listings.select_dtypes(include=['int64']).head()
# Out:
#      id       scrape_id  host_id  accommodates  guests_included  \
# 0  2595  20190806030549     2845             2                2
# 1  3647  20190806030549     4632             2                2
# 2  3831  20190806030549     4869             3                1
# 3  5022  20190806030549     7192             1                1
# 4  5099  20190806030549     7322             2                2
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               1            1125                       1
# 1               3               7                       3
# 2               1             730                       1
# 3              10             120                      10
# 4               3              21                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       1                    1125                    1125
# 1                       3                       7                       7
# 2                       1                     730                     730
# 3                      10                     120                     120
# 4                       3                      21                      21
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               13               17               31               288
# 1               30               60               90               365
# 2                0                1                4               212
# 3                0                0                0                 0
# 4               24               33               63               127
#
#    number_of_reviews  number_of_reviews_ltm  calculated_host_listings_count  \
# 0                 46                     12                               2
# 1                  0                      0                               1
# 2                274                     70                               1
# 3                  9                      2                               1
# 4                 75                     10                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0

# %%
drop_cols = drop_object_cols + drop_float_cols + drop_int_cols
len(drop_cols)
# Out:
# 38

# %%
drop_cols
# Out:
# ['listing_url',
#  'last_scraped',
#  'name',
#  'picture_url',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'calendar_updated',
#  'calendar_last_scraped',
#  'first_review',
#  'last_review',
#  'thumbnail_url',
#  'medium_url',
#  'xl_picture_url',
#  'latitude',
#  'longitude',
#  'scrape_id',
#  'host_id',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights']

# %%
df_dl_clean_df = df_detailed_listings.drop(columns=drop_cols)

# %%
df_dl_clean_df.shape
# Out:
# (48864, 68)

# %% [markdown]
# ## Missing Value analysis
# Calculate missing value statistics

# %%
print(pd.get_option("display.max_rows"))
pd.set_option("display.max_rows", 100)
print(pd.get_option("display.max_rows"))
# Out:
# -1
# 100

# %%
df_dl_clean_df.shape[0]
# Out:
# 48864

# %%
num_missing = df_dl_clean_df.isnull().sum().to_frame()
num_missing.columns = ['num_missing']
num_missing['pct_missing'] = np.round(100 * (num_missing['num_missing'] / df_dl_clean_df.shape[0]))
num_missing.sort_values(by='num_missing', ascending=False)
# Out:
#                                               num_missing  pct_missing
# host_acceptance_rate                                48864        100.0
# jurisdiction_names                                  48853        100.0
# license                                             48842        100.0
# square_feet                                         48469         99.0
# monthly_price                                       43715         89.0
# weekly_price                                        42964         88.0
# notes                                               28692         59.0
# access                                              21916         45.0
# interaction                                         19947         41.0
# house_rules                                         18912         39.0
# neighborhood_overview                               17297         35.0
# security_deposit                                    17290         35.0
# transit                                             16975         35.0
# host_response_rate                                  16582         34.0
# host_response_time                                  16582         34.0
# space                                               13985         29.0
# review_scores_location                              11163         23.0
# review_scores_value                                 11161         23.0
# review_scores_checkin                               11158         23.0
# review_scores_accuracy                              11142         23.0
# review_scores_communication                         11136         23.0
# review_scores_cleanliness                           11126         23.0
# review_scores_rating                                11104         23.0
# cleaning_fee                                        10584         22.0
# reviews_per_month                                   10131         21.0
# summary                                              2075          4.0
# description                                           843          2.0
# bathrooms                                              56          0.0
# beds                                                   42          0.0
# bedrooms                                               27          0.0
# host_has_profile_pic                                   18          0.0
# host_total_listings_count                              18          0.0
# host_listings_count                                    18          0.0
# host_is_superhost                                      18          0.0
# host_identity_verified                                 18          0.0
# cancellation_policy                                     1          0.0
# is_location_exact                                       0          0.0
# instant_bookable                                        0          0.0
# require_guest_profile_picture                           0          0.0
# experiences_offered                                     0          0.0
# requires_license                                        0          0.0
# require_guest_phone_verification                        0          0.0
# calculated_host_listings_count                          0          0.0
# calculated_host_listings_count_entire_homes             0          0.0
# host_verifications                                      0          0.0
# calculated_host_listings_count_private_rooms            0          0.0
# calculated_host_listings_count_shared_rooms             0          0.0
# is_business_travel_ready                                0          0.0
# number_of_reviews                                       0          0.0
# number_of_reviews_ltm                                   0          0.0
# extra_people                                            0          0.0
# bed_type                                                0          0.0
# amenities                                               0          0.0
# price                                                   0          0.0
# accommodates                                            0          0.0
# room_type                                               0          0.0
# property_type                                           0          0.0
# guests_included                                         0          0.0
# minimum_nights                                          0          0.0
# availability_365                                        0          0.0
# maximum_nights                                          0          0.0
# minimum_nights_avg_ntm                                  0          0.0
# maximum_nights_avg_ntm                                  0          0.0
# has_availability                                        0          0.0
# availability_30                                         0          0.0
# availability_60                                         0          0.0
# availability_90                                         0          0.0
# id                                                      0          0.0

# %%
df_dl_clean_df.amenities[0]
# Out:
# '{TV,Wifi,"Air conditioning",Kitchen,"Paid parking off premises","Free street parking","Indoor fireplace",Heating,"Family/kid friendly","Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Keypad,"Private living room",Bathtub,"Hot water","Bed linens","Extra pillows and blankets","Ethernet connection","Coffee maker",Refrigerator,"Dishes and silverware","Cooking basics",Oven,Stove,"Luggage dropoff allowed","Long term stays allowed","Cleaning before checkout","Wide entrance for guests","Flat path to guest entrance","Well-lit path to entrance","No stairs or steps to enter"}'

# %%
df_dl_clean_df.amenities[1]
# Out:
# '{"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,"Buzzer/wireless intercom",Heating,"Smoke detector","Carbon monoxide detector","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'

# %%
df_dl_clean_df.amenities[2]
# Out:
# '{TV,"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,"Pets allowed","Free street parking",Heating,"Family/kid friendly","Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door","24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Lockbox,Bathtub,"High chair","Stair gates","Children’s books and toys","Pack ’n Play/travel crib","Hot water","Luggage dropoff allowed","Long term stays allowed"}'

# %%
df_dl_clean_df.amenities[3]
# Out:
# '{Internet,Wifi,"Air conditioning",Kitchen,Elevator,"Free street parking","Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,"Hair dryer","Hot water","Host greets you"}'
